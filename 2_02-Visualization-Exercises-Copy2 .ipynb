# %% [markdown]
# [plt.show() Visualization with Matplotlib](https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html)

# %% [markdown]
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Visualization Exercise
#
# ## The Data
#
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds. It's a great dataset for beginners learning to work with data analysis and visualization.
#
# #### Content
#
# * price price in US dollars (\$326--\$18,823)
#
# * carat weight of the diamond (0.2--5.01)
#
# * cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# * color diamond colour, from J (worst) to D (best)
#
# * clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# * x length in mm (0--10.74)
#
# * y width in mm (0--58.9)
#
# * z depth in mm (0--31.8)
#
# * depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# * table width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
diamonds = pd.read_csv('../DATA/diamonds.csv')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#test 
cor = diamonds.corr()
cor
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
ax = sns.kdeplot(cor.depth, cor.carat, shade=True) #bivariate density

# %%
#tst univariate, bivariate density
import numpy as np; np.random.seed(10)
import seaborn as sns
sns.set(color_codes=True)
mean, cov = [0, 2], [(1, .5), (.5, 1)]
x, y = np.random.multivariate_normal(mean, cov, size=50).T

# %%
np.random.multivariate_normal(mean, cov, size=50)
# Out:
# array([[ 0.85199154,  0.94453465],
#        [ 0.56438715,  3.03413859],
#        [ 0.32509446,  1.92495611],
#        [-0.16777477,  2.68043384],
#        [-0.21849867,  0.99423241],
#        [-0.01829048,  1.51090226],
#        [-1.71252868, -0.45188542],
#        [ 0.44535861,  2.09647669],
#        [ 0.30965579,  2.45075996],
#        [ 0.57281773,  0.95424698],
#        [ 1.1565545 ,  1.83610696],
#        [-2.30324776,  2.16207732],
#        [-1.37103081,  0.97520231],
#        [-0.96893006,  1.19788021],
#        [-1.76870349,  0.89918612],
#        [ 0.76391523,  1.63436404],
#        [ 0.39730861,  2.71113913],
#        [ 1.17250167,  2.95070853],
#        [-1.17506508,  0.85424463],
#        [-2.44297729,  1.00418831],
#        [ 0.92874967,  1.56943909],
#        [ 0.28199868,  1.80121134],
#        [-1.13434776,  2.48006022],
#        [ 1.1670006 ,  2.77827265],
#        [-0.85531009,  2.27966309],
#        [-0.64944047,  1.76485717],
#        [-1.41117162,  1.0823437 ],
# ...

# %%
ax = sns.kdeplot(x)

# %%
ax = sns.kdeplot(x, shade=True, color="r")

# %%
ax = sns.kdeplot(x, y, shade=True)

# %%
mypalette2 = sns.cubehelix_palette(n_colors=6, start=5, rot=0.4, gamma=1.0, hue=0.8, light=0.85, dark=0.15, reverse=False, as_cmap=False)
sns.palplot(mypalette2)

# %%
#as_cmap=True
mypalette3 = sns.cubehelix_palette(n_colors=6, start=5, rot=0.4, gamma=1.0, hue=0.8, light=0.85, dark=0.15, reverse=False, as_cmap=True)

# %%
cmap = mypalette3
sns.heatmap(diamonds.corr(), cmap = cmap)

# %%
sns.heatmap(diamonds.corr())

# %% [markdown]
# ### [seaborn tutorial](https://seaborn.pydata.org/tutorial.html)

# %% [markdown]
# #### TASK: Create a scatterplot of price versus carat as shown below

# %%
# CODE HERE
sns.scatterplot(x='carat',y='price',data=diamonds)

# %% [markdown]
# #### TASK: Use alpha parameter and edgecolor parameter to deal with the overlapping issue and white edgemarker issue.

# %%
# CODE HERE
# CODE HERE
# the scale for alpha is between 0 and 1, with 1 being fully opaque and 0 being fully transparent.
#"edgecolor": (1,0,0,1), edgecolor = 'none'
sns.scatterplot(x='carat',y='price',edgecolor = 'None'
,alpha = .1, data=diamonds)

# %% [markdown]
# #### TASK: Make the previous plot larger

# %%
# CODE HERE
# CODE HERE
plt.figure(figsize=(12,8))
sns.scatterplot(x='carat',y='price',edgecolor = 'None'
,alpha = .1, data=diamonds)

# %% [markdown]
# [sns.distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %% [markdown]
# #### TASK: Create a histogram of the price column as shown below

# %%
sns.distplot(diamonds['price'])

# %%
# CODE HERE
plt.figure(figsize=(12, 8))
sns.distplot(diamonds['price'])

# %%
plt.figure(figsize=(12, 8))
sns.distplot(diamonds['price'], kde = False)

# %% [markdown]
# #### TASK: Create a count plot of the instances per cut type as shown below

# %%
# CODE HERE
sns.countplot(x='cut',data=diamonds)

# %% [markdown]
# #### TASK: Create a large box plot figure showing the price distribution per cut type as shown below

# %%
# CODE HERE
plt.figure(figsize=(12, 8))
sns.boxplot(x='cut',y='price',data=diamonds)

# %% [markdown]
# #### TASK: Challenge! See if you can figure out how to change the ordering of the boxplot as shown below. Feel free to also chaneg the coloring, to reflect this relationship between the cut types.

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#test * count the frequencies of the element in dataframe value

# %%
# CODE HERE
cut_list = ['Fair','Ideal','Good', 'Very Good','Premium' ]
diamonds2 = diamonds[['cut', 'price']]
diamonds2.head()
diamonds['cut'].value_counts()
# diamonds[diamonds['cut']]
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
diamonds2
# Out:
#              cut  price
# 0          Ideal    326
# 1        Premium    326
# 2           Good    327
# 3        Premium    334
# 4           Good    335
# ...          ...    ...
# 53935      Ideal   2757
# 53936       Good   2757
# 53937  Very Good   2757
# 53938    Premium   2757
# 53939      Ideal   2757
#
# [53940 rows x 2 columns]

# %%
cut_order= ['Fair','Ideal','Good', 'Very Good','Premium' ]
plt.figure(figsize=(12,8))
sns.boxplot(x='cut',y='price',data=diamonds, order=cut_order, palette='cool')

# %% [markdown]
# #### value_counts() : frequency of each cut

# %%
#test 1
print(type(diamonds['cut'].value_counts())) #Series
diamonds['cut'].value_counts()
# Out:
# <class 'pandas.core.series.Series'>
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#test 1
cut1 = pd.DataFrame(diamonds['cut'].value_counts())
cut1
# Out:
#              cut
# Ideal      21551
# Premium    13791
# Very Good  12082
# Good        4906
# Fair        1610

# %%
plt.plot(cut1);
plt.title('cut-wise frequency count chart')
plt.xlabel('cut')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
cut1.plot();

# %%
#change index to column -> df.reset_index()
reset_index_cut1 = cut1.reset_index()
reset_index_cut1
# Out:
#        index    cut
# 0      Ideal  21551
# 1    Premium  13791
# 2  Very Good  12082
# 3       Good   4906
# 4       Fair   1610

# %%
sns.scatterplot(x= 'index', y='cut', data=reset_index_cut1)

# %%
#test 2
cutdict = diamonds['cut'].value_counts().to_dict()
cutdict
# Out:
# {'Ideal': 21551,
#  'Premium': 13791,
#  'Very Good': 12082,
#  'Good': 4906,
#  'Fair': 1610}

# %%
pd.DataFrame(list(cutdict.items()))
# Out:
#            0      1
# 0      Ideal  21551
# 1    Premium  13791
# 2  Very Good  12082
# 3       Good   4906
# 4       Fair   1610

# %%
countcutdf = pd.DataFrame([cutdict])
countcutdf
# Out:
#    Ideal  Premium  Very Good  Good  Fair
# 0  21551    13791      12082  4906  1610

# %%
#test
new_dict = {'key 1': 'value 1', 'key 2': 'value 2', 'key 3': 'value 3'}
newdf = pd.DataFrame([new_dict])
newdf
# Out:
#      key 1    key 2    key 3
# 0  value 1  value 2  value 3
